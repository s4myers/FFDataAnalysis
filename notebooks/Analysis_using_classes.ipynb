# %%
import sys
sys.path.append("../scripts/")
from Data_Analysis import *

# %%
#So I created 4 child classes that inherent from a parent class, so far the only method I have is 
#totaling a given stat.  Here is what I have so far
luck = QuarterBack(" Andrew Luck","IND")
dez = WideReceiver(" Dez Bryant","DAL")
jimmy = TightEnd(" Jimmy Graham","NO")
beast = RunningBack(" Marshawn Lynch","SEA")

# %%
# Example of how we can use this to look up a player's stats
# e.g. Cutler's week 6 2014 game stats
luck.stats["2014"]["7"]
# Out:
# {'Avg': '1.3',
#  'Comp': '27',
#  'FUM': '1',
#  'G': '1',
#  'GS': '1',
#  'Game Date': '10/19',
#  'Int': '0',
#  'Lost': '1',
#  'Opp': 'CIN',
#  'PassAtt': '42',
#  'PassTD': '2',
#  'PassYds': '344',
#  'Pct': '64.3',
#  'Player': ' Andrew Luck',
#  'Rate': '105.7',
#  'Result': 'W\xc2\xa027-0',
#  'RushAtt': '4',
#  'RushTD': '0',
#  'RushYds': '5',
#  'Sck': '2',
#  'SckY': '9',
#  'WK': '7',
#  'Year': '2014'}

# %%
#This shows how we can select just a few weeks or the whole season
print "Pass Yards by Luck in Championship weeks: %s"%luck.total("PassYds","2014",weeks=["14","15","16"])
print "Pass TDs by Luck for the year: %s"%luck.total("PassTD","2014")
print "Total rush TDs from Beast Mode: %s"%beast.total("RushTD","2014")
print "Total Beast Mode Receptions: %s" %beast.total("Rec","2014")
print "Jimmy's receptions in '14: %s"%jimmy.total("Rec","2014")
print "Jimmy's receptions in '13: %s"%jimmy.total("RecTD","2013")
#Also, added some error detection
jimmy.total("Broken Legs","2012",weeks="7")
# Out:
# Pass Yards by Luck in Championship weeks: 590.0
# Pass TDs by Luck for the year: 40.0
# Total rush TDs from Beast Mode: 13.0
# Total Beast Mode Receptions: 37.0
# Jimmy's receptions in '14: 85.0
# Jimmy's receptions in '13: 16.0
# Not a valid field. Please choice from:
# ['G', 'GS', 'RushAtt', 'RushYds', 'RushAvg', 'RushLng', 'RushTD', 'Rec', 'RecYds', 'RecAvg', 'RecLng', 'RecTD', 'FUM', 'Lost']

# %%
# Adding ability to find average and standard deviation
# We can further expand to compare with league averages
#compare Luck and Rogers
rodgers = QuarterBack(" Aaron Rodgers","GB")
print "Luck's 2014 weekly average was %.2f yds \
with std of %.2f yds"% (luck.average("PassYds","2014"),luck.standard_dev("PassYds","2014"))
print "Rodgers' 2014 weekly average was %.2f yds \
with std of %.2f yds"% (rodgers.average("PassYds","2014"),rodgers.standard_dev("PassYds","2014"))
# Out:
# Luck's 2014 weekly average was 297.56 yds with std of 90.36 yds
# Rodgers' 2014 weekly average was 273.81 yds with std of 77.08 yds

# %%
# Checking out beastmode
print "Lynch's 2014 weekly average was %.2f yds \
with std of %.2f yds"% (beast.average("RushYds","2014"),beast.standard_dev("RushYds","2014"))
# Out:
# Lynch,s 2014 weekly average was 81.62 yds with std of 29.52 yds
