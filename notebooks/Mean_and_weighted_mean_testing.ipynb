# %%
import sys
sys.path.append("../scripts/")
from Data_Analysis import *
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline

# %%
# Test class functions
luck = QuarterBack(" Andrew Luck","IND")
stafford = QuarterBack(" Matthew Stafford","DET")
forte = RunningBack(" Matt Forte","CHI")

# %%
avg = luck.ppg_average("2014")
var = np.sqrt(luck.ppg_var("2014"))
print "Andrew Luck averaged %.2f points per game with a variance of %.2f points per game" % (avg,var)
# Out:
# Andrew Luck averaged 21.98 points per game with a variance of 8.06 points per game

# %%
avg = stafford.ppg_average("2014")
var = np.sqrt(stafford.ppg_var("2014"))
print "Matt Stafford averaged %.2f points per game with a variance of %.2f points per game" % (avg,var)
# Out:
# Matt Stafford averaged 15.60 points per game with a variance of 7.28 points per game

# %%
avg = forte.ppg_average("2014")
var = np.sqrt(forte.ppg_var("2014"))
print "Matt Forte averaged %.2f points per game with a variance of %.2f points per game" % (avg,var)
# Out:
# Matt Forte averaged 18.23 points per game with a variance of 7.64 points per game
