# %%
import csv
import os
main_dir = "Users/sean/Documents/GitHub/FFDataAnalysis/CSV_data"

# %%
def points_allowed(team,pos,year, 
                   ptd = 6.0,rtd = 4.0,
                   ryard = .1, pyard = 0.04,
                   ppr = 1.0,
                   tover = -2.0):
    """
    This fuction generates the fantasy points allowed for a given year.

    Keyword arguments:
    team  -- the nfl team name
    pos   -- the position that the team allowed points too
    year  -- the year 
    rtd   -- points per rush touchdown allowed
    ptd   -- points per pass touchdown allowed
    ryard -- points per rush yard allowed
    pyard -- points per pass allowed
    ppr   -- points per reception allowed
    tover -- points lost by player due to a turnover
    """
    
    # Initialize variables
    tot_ryards = 0.0
    tot_pyards = 0.0
    tot_rec = 0
    tot_rtd = 0
    tot_ptd = 0
    tot_tover = 0
    

    # setup of paths
    csv_file_name = pos +"Stats.csv"
    csv_path = os.path.join("c:/",main_dir,csv_file_name)
    
    # read from the csv file and get total points allowed to a QB
    with open(csv_path) as csv_file:
        reader = csv.DictReader(csv_file)
        for row in reader:
            if (row["Opp"]==team or row["Opp"]=='@'+team) and row["Year"]==year and row["GS"]=="1":
                tot_pyards += 0.0 if row["PYds"]=="--" else float(row["PYds"])
                tot_ryards += 0.0 if row["RYds"]=="--" else float(row["RYds"])
                tot_ptd += 0.0 if row["PTD"]=="--" else float(row["PTD"])
                tot_rtd += 0.0 if row["RTD"]=="--" else float(row["RTD"])
                tot_tover += 0.0 if row["Lost"]=="--" else int(row["Lost"])
                tot_tover += 0.0 if row["Int"]=="--" else int(row["Int"])
    tot_points = tot_pyards*pyard + tot_ryards*ryard + \
                 tot_ptd*ptd + tot_rtd*rtd - tot_tover*tover
    return (team,tot_points)

# %%
team_list =["BUF","MIA","NE","NYJ","BAL","CIN","CLE","PIT","HOU","IND","JAC","TEN","DEN","KC","OAK","SD","DAL","NYG","PHI","WAS",
            "CHI","DET","GB","MIN","ATL","CAR","NO","TB","ARI","STL","SF","SEA"]
year_list = ["2010","2011","2012","2013","2014"]

# %%
points_allowed_QB_dict={year:sorted([points_allowed(team,"QB",year) for team in team_list], \
                                 key=lambda x: x[1],reverse=True) for year in year_list}

# %%
# Ranking doesn't match NFL.com
print "2010\t\t2011\t\t2012\t\t2013\t\t2014"
for i in range(32):
    print "%d.%s-%.2f\t%d.%s-%.2f\t%d.%s-%.2f\t%d.%s-%.2f\t%d.%s-%.2f"% \
   (i+1,points_allowed_QB_dict["2010"][i][0],points_allowed_QB_dict["2010"][i][1],
    i+1,points_allowed_QB_dict["2011"][i][0],points_allowed_QB_dict["2011"][i][1],
    i+1,points_allowed_QB_dict["2012"][i][0],points_allowed_QB_dict["2012"][i][1],
    i+1,points_allowed_QB_dict["2013"][i][0],points_allowed_QB_dict["2013"][i][1],
    i+1,points_allowed_QB_dict["2014"][i][0],points_allowed_QB_dict["2014"][i][1])
# Out:
# 2010		2011		2012		2013		2014
# 1.NE-369.36	1.GB-390.46	1.WAS-433.98	1.MIN-454.76	1.CHI-441.38
# 2.SEA-334.74	2.TB-372.20	2.TB-432.28	2.DAL-453.94	2.PHI-424.96
# 3.CLE-330.14	3.MIN-365.64	3.NO-426.90	3.TB-435.98	3.WAS-421.78
# 4.MIN-301.52	4.OAK-361.66	4.TEN-399.86	4.ARI-420.70	4.NO-401.26
# 5.HOU-294.26	5.DET-357.92	5.PHI-387.94	5.ATL-418.02	5.NYG-387.34
# 6.OAK-293.84	6.NE-350.58	6.NE-383.36	6.OAK-410.82	6.ARI-384.84
# 7.CIN-293.14	7.IND-329.96	7.MIN-374.58	7.GB-403.16	7.TB-381.08
# 8.SF-291.34	8.BUF-325.54	8.NYG-369.62	8.DEN-386.00	8.GB-377.12
# 9.PHI-287.04	9.NO-319.82	9.KC-362.36	9.CLE-379.50	9.PIT-365.70
# 10.ATL-281.80	10.MIA-317.60	10.BUF-355.66	10.IND-377.46	10.CAR-360.66
# 11.NYJ-279.04	11.ATL-316.98	11.SD-352.16	11.PHI-362.88	11.ATL-356.08
# 12.CAR-273.62	12.NYG-312.42	12.OAK-345.66	12.DET-359.20	12.SF-355.90
# 13.PIT-269.32	13.CHI-307.74	13.CLE-334.04	13.BUF-354.24	13.DEN-353.32
# 14.BAL-266.64	14.CAR-305.42	14.JAC-332.18	14.JAC-353.08	14.MIA-353.24
# 15.BUF-254.20	15.JAC-305.08	15.DEN-325.56	15.WAS-351.98	15.HOU-350.08
# 16.DEN-250.54	16.SD-297.74	16.GB-320.58	16.KC-349.72	16.BAL-350.04
# 17.MIA-250.26	17.DEN-294.52	17.CHI-310.20	17.NE-349.16	17.SD-349.72
# 18.DET-248.58	18.PHI-265.58	18.CAR-308.38	18.BAL-329.76	18.JAC-341.24
# 19.ARI-243.52	19.TEN-262.40	19.DAL-306.14	19.MIA-325.00	19.TEN-341.02
# 20.DAL-239.28	20.HOU-260.90	20.STL-298.42	20.CHI-324.26	20.DAL-338.58
# 21.WAS-232.38	21.KC-252.02	21.DET-294.92	21.NO-322.94	21.DET-336.38
# 22.JAC-216.08	22.ARI-249.04	22.ARI-293.84	22.CIN-321.92	22.OAK-330.84
# 23.TEN-213.08	23.WAS-243.28	23.ATL-293.60	23.HOU-321.54	23.NE-330.62
# 24.STL-211.32	24.DAL-241.18	24.CIN-289.78	24.NYJ-318.08	24.NYJ-329.72
# 25.TB-207.10	25.NYJ-230.94	25.IND-289.66	25.NYG-316.14	25.IND-324.70
# 26.NO-202.54	26.BAL-229.54	26.HOU-287.22	26.STL-315.40	26.STL-323.74
# 27.CHI-194.20	27.STL-228.66	27.SF-278.98	27.CAR-314.32	27.CIN-323.42
# 28.GB-191.90	28.SF-223.04	28.MIA-278.70	28.TEN-312.16	28.MIN-316.68
# 29.SD-186.36	29.SEA-210.14	29.SEA-259.06	29.SD-308.10	29.CLE-309.02
# 30.KC-182.74	30.CLE-203.40	30.NYJ-258.54	30.SF-294.12	30.BUF-273.86
# 31.NYG-150.30	31.CIN-197.86	31.PIT-247.06	31.SEA-288.60	31.SEA-265.00
# 32.IND-118.52	32.PIT-184.78	32.BAL-221.94	32.PIT-286.62	32.KC-239.90
