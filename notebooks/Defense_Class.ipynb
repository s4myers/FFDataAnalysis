# %%
import sys
sys.path.append("/home/sean/Projects/FFDataAnalysis/scripts/")
from Data_Analysis import *

# %%
b = Kicker(" Dan Bailey")

# %%
b.stats["2014"]["1"]
# Out:
# {'DistAvg': '52',
#  'FGAtt': '1',
#  'FGBlk': '0',
#  'FGLng': '29',
#  'FGM': '1',
#  'FGPct': '100',
#  'G': '1',
#  'GS': '0',
#  'Game Date': '7-Sep',
#  'KO': '4',
#  'Opp': 'SF',
#  'Player': ' Dan Bailey',
#  'Result': 'L17-28',
#  'Ret': '0',
#  'RetAvg': '--',
#  'TB': '3',
#  'WK': '1',
#  'XPAtt': '2',
#  'XPBlk': '0',
#  'XPM': '2',
#  'XPPct': '100',
#  'Year': '2014'}

# %%
# Out:
# 25.0
