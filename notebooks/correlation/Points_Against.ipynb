# %%
import sys
sys.path.append("/home/sean/Projects/FFDataAnalysis/scripts/")
from Data_Analysis import *
% matplotlib inline

# %%
test_dict =points_against(["QB","RB"])

# %%
d =test_dict["QB"]["2014"]
d
# Out:
# {'ARI': 254.88000000000005,
#  'ATL': 226.29999999999995,
#  'BAL': 247.72,
#  'BUF': 158.05999999999997,
#  'CAR': 223.12,
#  'CHI': 259.03999999999996,
#  'CIN': 190.49999999999997,
#  'CLE': 194.29999999999998,
#  'DAL': 237.72,
#  'DEN': 226.1,
#  'DET': 184.49999999999997,
#  'GB': 226.4799999999999,
#  'HOU': 221.36,
#  'IND': 239.62000000000003,
#  'JAC': 236.00000000000003,
#  'KC': 152.24,
#  'MIA': 216.0,
#  'MIN': 209.84,
#  'NE': 201.88000000000005,
#  'NO': 261.48,
#  'NYG': 247.68,
#  'NYJ': 235.02000000000007,
#  'OAK': 210.68,
#  'PHI': 259.68,
#  'PIT': 252.37999999999997,
#  'SD': 257.58000000000004,
#  'SEA': 155.45999999999998,
#  'SF': 190.31999999999996,
#  'STL': 212.14,
#  'TB': 236.44,
#  'TEN': 236.1,
#  'WAS': 308.21999999999997}

# %%
[(i,d[i]) for i in sorted(d,key=d.get,reverse=True)]
# Out:
# [('WAS', 308.21999999999997),
#  ('NO', 261.48),
#  ('PHI', 259.68),
#  ('CHI', 259.03999999999996),
#  ('SD', 257.58000000000004),
#  ('ARI', 254.88000000000005),
#  ('PIT', 252.37999999999997),
#  ('BAL', 247.72),
#  ('NYG', 247.68),
#  ('IND', 239.62000000000003),
#  ('DAL', 237.72),
#  ('TB', 236.44),
#  ('TEN', 236.1),
#  ('JAC', 236.00000000000003),
#  ('NYJ', 235.02000000000007),
#  ('GB', 226.4799999999999),
#  ('ATL', 226.29999999999995),
#  ('DEN', 226.1),
#  ('CAR', 223.12),
#  ('HOU', 221.36),
#  ('MIA', 216.0),
#  ('STL', 212.14),
#  ('OAK', 210.68),
#  ('MIN', 209.84),
#  ('NE', 201.88000000000005),
#  ('CLE', 194.29999999999998),
#  ('CIN', 190.49999999999997),
#  ('SF', 190.31999999999996),
#  ('DET', 184.49999999999997),
#  ('BUF', 158.05999999999997),
#  ('SEA', 155.45999999999998),
#  ('KC', 152.24)]

# %%
308/16.0
# Out:
# 19.25
